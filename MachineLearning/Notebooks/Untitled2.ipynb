# %%
d = {}

# %%
d
# Out:
# {}

# %%
print(d)
# Out:
# {}

# %%
d[]
# Out:
#   File "<ipython-input-4-2e87dd0ce60a>", line 1
#     d[]
#       ^
# SyntaxError: invalid syntax

# %%
d["a"]=1

# %%
d
# Out:
# {'a': 1}
