# %% [markdown]
# # Caffeinated Logistic Regression of HDF5 Data

# %% [markdown]
# 该例子是利用Caffe完成一个浅层模型的训练，这里使用手工生成的数据训练一个logistic regression for classification。手工生成的数据将保存到HDF5中，然后以向量的形式输入到Caffe中。例子中分别对比了sklearn-learn库和两个Caffe模型进行训练和预测，对比了训练时间和精度，可以看到Caffe在较少的时间内可以获得较高的训练精度。
#
# 整个过程包括：定义模型、实验和部署。l
#
# 本文为了运行于本机，只做了细微修改和中文说明，原始文件来源于Caffe官网对应的Notebook Examples。http://nbviewer.ipython.org/github/BVLC/caffe/blob/master/examples/hdf5_classification.ipynb
#
#
# <p style="text-align:right;"> ---Last update 2015年6月7日</p>

# %% [markdown]
# ### Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# 切换工作目录到 caffe-master
# %cd '/home/ouxinyu/caffe-master'

# Make sure that caffe is on the python path:
caffe_root = './'  # this file is expected to be in {caffe_root}/examples
import sys
sys.path.insert(0, caffe_root + 'python')

import caffe

import os
import h5py
import shutil
import tempfile

# You may need to 'pip install scikit-learn'
import sklearn
import sklearn.datasets
import sklearn.linear_model
# Out:
# /home/ouxinyu/caffe-master

# %% [markdown]
# ### 生成训练数据

# %% [markdown]
# 生成10000个4-vectors的向量用于binary分类，包含2种informative feature和2种noise features。

# %%
X, y = sklearn.datasets.make_classification(
    n_samples=10000, n_features=4, n_redundant=0, n_informative=2, 
    n_clusters_per_class=2, hypercube=False, random_state=0
)

# Split into train and test
X, Xt, y, yt = sklearn.cross_validation.train_test_split(X, y)

# Visualize sample of the data
ind = np.random.permutation(X.shape[0])[:1000]
df = pd.DataFrame(X[ind])
_ = pd.scatter_matrix(df, figsize=(9, 9), diagonal='kde', marker='o', s=40, alpha=.4, c=y[ind])

# %% [markdown]
# ### 使用Python的sklearn库进行训练和预测

# %% [markdown]
# 学习和评估sklearn-learn的logistic regression，使用SGD算法进行训练，算法演示了使用sklearn获得的预测结果和测试时间。其中sklearn是python的一个机器学习的库。

# %%
# Train and test the scikit-learn SGD logistic regression.
clf = sklearn.linear_model.SGDClassifier(
    loss='log', n_iter=1000, penalty='l2', alpha=1e-3, class_weight='auto')

# %timeit clf.fit(X, y)
yt_pred = clf.predict(Xt)
print('Accuracy: {:.3f}'.format(sklearn.metrics.accuracy_score(yt, yt_pred)))
# Out:
# 1 loops, best of 3: 393 ms per loop
# Accuracy: 0.767

# %% [markdown]
# ### 使用Caffe的模型一进行训练和预测

# %% [markdown]
# 将生成的随机数据保存到HDF5种，并作为Caffe到输入数据。

# %%
# Write out the data to HDF5 files in a temp directory.
# This file is assumed to be caffe_root/examples/hdf5_classification.ipynb
dirname = os.path.abspath('examples/hdf5_classification/data')
if not os.path.exists(dirname):
    os.makedirs(dirname)

train_filename = os.path.join(dirname, 'train.h5')
test_filename = os.path.join(dirname, 'test.h5')

# HDF5DataLayer source should be a file containing a list of HDF5 filenames.
# To show this off, we'll list the same data file twice.
with h5py.File(train_filename, 'w') as f:
    f['data'] = X
    f['label'] = y.astype(np.float32)
with open(os.path.join(dirname, 'train.txt'), 'w') as f:
    f.write(train_filename + '\n')
    f.write(train_filename + '\n')
    
# HDF5 is pretty efficient, but can be further compressed.
comp_kwargs = {'compression': 'gzip', 'compression_opts': 1}
with h5py.File(test_filename, 'w') as f:
    f.create_dataset('data', data=Xt, **comp_kwargs)
    f.create_dataset('label', data=yt.astype(np.float32), **comp_kwargs)
with open(os.path.join(dirname, 'test.txt'), 'w') as f:
    f.write(test_filename + '\n')

# %% [markdown]
# 因为我的起始位置都定义成~/caffe-master$ 所以下面的路径需要做一定的修改，同时建议把运行模式也修改成GPU，让Caffe运行在GPU模式下，方法如下：

# %% [markdown]
# <p style="color:Blue;">~/caffe-master$ gedit examples/hdf5_classification/solver.prototxt</p>
#
# <p style="color:Blue;">~/caffe-master$ gedit examples/hdf5_classification/solver2.prototxt</p>
#
# <p style="color:Red;padding-left:30px;">
#     net: "examples/hdf5_classification/train_val.prototxt"<br/>
#     snapshot_prefix: "examples/hdf5_classification/data/train"<br/>
#     solver_mode: GPU
# </p>
#
# <p style="color:Blue;">~/caffe-master$  gedit examples/hdf5_classification/train_val.prototxt</p>
#
# <p style="color:Blue;">~/caffe-master$ gedit examples/hdf5_classification/train_val2.prototxt</p>
#
# <p style="color:Red;padding-left:30px;">
#     source: "examples/hdf5_classification/data/train.txt"<br/>
#     source: "examples/hdf5_classification/data/test.txt"
# </p>

# %% [markdown]
# 使用Caffe来学习和评估logistic regression的效果，可以看到模型一到效果比sklearn-learn略微差一点，但是速度快很多。

# %%
def learn_and_test(solver_file):
    caffe.set_mode_cpu()
    solver = caffe.get_solver(solver_file)
    solver.solve()

    accuracy = 0
    test_iters = int(len(Xt) / solver.test_nets[0].blobs['data'].num)
    for i in range(test_iters):
        solver.test_nets[0].forward()
        accuracy += solver.test_nets[0].blobs['accuracy'].data
    accuracy /= test_iters
    return accuracy

# %timeit learn_and_test('examples/hdf5_classification/solver.prototxt')
acc = learn_and_test('examples/hdf5_classification/solver.prototxt')
print("Accuracy: {:.3f}".format(acc))
# Out:
# 1 loops, best of 3: 144 ms per loop
# Accuracy: 0.768

# %% [markdown]
# 使用命令行接口来执行同样的工作，获得的精度是一样。

# %%
! build/tools/caffe train -solver examples/hdf5_classification/solver.prototxt
# Out:
# I0607 13:37:51.712443  4006 caffe.cpp:113] Use GPU with device ID 0
# I0607 13:37:51.875576  4006 caffe.cpp:121] Starting Optimization
# I0607 13:37:51.875680  4006 solver.cpp:32] Initializing solver from parameters:
# test_iter: 250
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "examples/hdf5_classification/data/train"
# solver_mode: GPU
# net: "examples/hdf5_classification/train_val.prototxt"
# I0607 13:37:51.875735  4006 solver.cpp:70] Creating training net from net file: examples/hdf5_classification/train_val.prototxt
# I0607 13:37:51.875921  4006 net.cpp:287] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I0607 13:37:51.875934  4006 net.cpp:287] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# ...

# %% [markdown]
# ### 使用Caffe的模型二进行训练和预测

# %% [markdown]
# solver.prototxt是一个单层FC层的logistic regression，为了改进accuracy，solver2.prototxt增加了一个FC层,变成了一个2层到网络，可以看到性能相比solver.prototxt和scikit-learn's logistic regression 都有较大到提升，而执行时间并没有显著增加，仍然比scikit少。

# %%
def learn_and_test(solver_file):
    caffe.set_mode_cpu()
    solver = caffe.get_solver(solver_file)
    solver.solve()

    accuracy = 0
    test_iters = int(len(Xt) / solver.test_nets[0].blobs['data'].num)
    for i in range(test_iters):
        solver.test_nets[0].forward()
        accuracy += solver.test_nets[0].blobs['accuracy'].data
    accuracy /= test_iters
    return accuracy

# %timeit learn_and_test('examples/hdf5_classification/solver2.prototxt')
acc = learn_and_test('examples/hdf5_classification/solver2.prototxt')
print("Accuracy: {:.3f}".format(acc))
# Out:
# 1 loops, best of 3: 201 ms per loop
# Accuracy: 0.832

# %% [markdown]
# 使用命令行方式运行同样模型和solver，获得了相同到精度。

# %%
! build/tools/caffe train -solver examples/hdf5_classification/solver2.prototxt
# Out:
# I0607 13:38:01.183537  4010 caffe.cpp:113] Use GPU with device ID 0
# I0607 13:38:01.340281  4010 caffe.cpp:121] Starting Optimization
# I0607 13:38:01.340370  4010 solver.cpp:32] Initializing solver from parameters:
# test_iter: 250
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "examples/hdf5_classification/data/train"
# solver_mode: GPU
# net: "examples/hdf5_classification/train_val2.prototxt"
# I0607 13:38:01.340425  4010 solver.cpp:70] Creating training net from net file: examples/hdf5_classification/train_val2.prototxt
# I0607 13:38:01.340648  4010 net.cpp:287] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I0607 13:38:01.340663  4010 net.cpp:287] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# ...

# %% [markdown]
# 删除实验到临时数据，包括输入数据.h5文件和获得的模型caffemodell。

# %% [markdown]
# ### 清理实验产生的临时文件

# %%
# Clean up (comment this out if you want to examine the hdf5_classification/data directory).
shutil.rmtree(dirname)
